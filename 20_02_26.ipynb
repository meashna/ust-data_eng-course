# %%
4+3
# Out:
# 7

# %%
lst=open(r'C:\Users\Administrator\Desktop\try.txt')
lst.close()

# %%
f = open("try.txt", "r")
content = f.read()
print(content)
f.close()
# Out:
# This is the 1st moduleThis is the second module

# %%
lst = open(r'C:\Users\Administrator\Desktop\try.txt')
lst.close()

# %%
import os
os.getenv("C:/Users/Administrator/Desktop")
lst=open("try.txt","w")
lst.write("This is the 1st module\n")
lst.write("This is the 2nd module")
lst.close()

# %%
text = "Hello World"
print(text[0:5])
# Out:
# Hello

# %%
lst=open("try.txt","r")
lst.read(4)
# Out:
# 'This'

# %%
lst.tell()
# Out:
# 4

# %%
lst.seek(5)
# Out:
# 5

# %%
lst.seek(8)
# Out:
# 8

# %%
lst.seek(0)
for line in lst:
    print(line)
# Out:
# This is the 1st module
#
# This is the 2nd module

# %%
lst=open("try.txt","r")
# lst.readline()
# Out:
# 'This is the 1st module\n'

# %%
lst=open("try.txt","r")
# lst.readlines()
# Out:
# ['This is the 1st module\n', 'This is the 2nd module']

# %%
import  os 

os.rename("try.txt","try2.txt")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[30], line 3
#       1 import  os
# ----> 3 os.rename("try.txt","try2.txt")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'try.txt' -> 'try2.txt'

# %%
os.remove("try.txt")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 os.remove("try.txt")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'try.txt'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  '20_02_26.ipynb',
#  'desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'Readme - Shortcut.lnk',
#  'try.txt',
#  'try1.txt.txt']

# %%
os.mkdir("new_dir")

# %%
os.listdir(os.getcwdb())
# Out:
# [b'.ipynb_checkpoints',
#  b'20_02_26.ipynb',
#  b'desktop.ini',
#  b'Microsoft Edge.lnk',
#  b'MongoDBCompass.lnk',
#  b'new_dir',
#  b'Readme - Shortcut.lnk',
#  b'try.txt',
#  b'try1.txt.txt']

# %%
import math 
print(math.pi)
# Out:
# 3.141592653589793

# %%
import datetime as dt
dt.datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 11, 31, 49, 905444)
