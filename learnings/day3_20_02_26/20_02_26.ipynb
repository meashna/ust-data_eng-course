# %%
3+4
# Out:
# 7

# %%
lst=open('C:\Users\Administrator\Desktop\try.txt')
lst.close()
# Out:
#   Cell In[4], line 1
#     lst=open('C:\Users\Administrator\Desktop\try.txt')
#              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
lst = open('C:/Users/Administrator/Desktop/try.txt')
lst.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 lst = open('C:/Users/Administrator/Desktop/try.txt')
#       2 lst.close()
#
# File /lib/python3.13/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 44] No such file or directory: 'C:/Users/Administrator/Desktop/try.txt'

# %%
import os
os.getenv("C:/Users/Administrator/Desktop")
lst=open("try.txt","w")
lst.write("This is the 1st module")
lst.write("This is the second module")
lst.close()
